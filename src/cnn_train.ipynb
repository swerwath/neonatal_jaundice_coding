# %%
import pickle
from random import shuffle, seed
import numpy as np
from util import plot_confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, precision_recall_curve
from keras.models import Sequential, Model, load_model
from keras.layers.convolutional import Conv1D
from keras.layers import Dense, Dropout, Flatten, Input, MaxPooling1D, Embedding, Lambda
from keras.layers.merge import Concatenate
from keras.preprocessing import sequence
from keras.callbacks import ModelCheckpoint
from keras.layers.normalization import BatchNormalization
from keras.layers import Activation
from keras.optimizers import Adam
from keras.layers.embeddings import Embedding
import tensorflow as tf

import warnings
warnings.filterwarnings('ignore') # get rid of silly sklearn warnings

seed("sahai uwu")

# %%
ppath = "/Volumes/scottd/mimic_processed/preproced.bin"
data = pickle.load(open(ppath, 'rb')) # Tuples of (text, label) where label is 0 or 1
shuffle(data)

split_point = int(0.8 * len(data)) # Use 80% of our data for training and the rest for testing
train = data[:split_point]
test = data[split_point:]

train_data = [t[0] for t in train]
train_labels = [t[1] for t in train]
test_data = [t[0] for t in test]
test_labels = [t[1] for t in test]

print("Number of training samples: " + str(len(train)))
print("Number of test samples: " + str(len(test)))
print(np.unique(train_labels, return_counts=True))
print(np.unique(test_labels, return_counts=True))

lens = [len(d) for d in train_data]
print(train_data[3])
lens = sorted(lens)
print("Median length: " + str(lens[int(len(lens) * .8)]))
# Out:
# Number of training samples: 5660
# Number of test samples: 1415
# (array([0, 1]), array([3365, 2295]))
# (array([0, 1]), array([841, 574]))
# unit_admission date discharge date date_birth sex_f service neonatology history present_illness infant born_weeks gestation_yearold g2_p0 mother prenatal_screens follows blood_type positive_antibody negative_hbsag negative_rpr nonreactive_rubella immune_gbs negative mother history bipolar_disorder treated lithium pregnancy_uncomplicated day prior_delivery seen obs_office noted elevated blood_pressures admitted hospital care observation upon monitoring baby nonreassuring_fetal heart_rate tracing mother delivered_cesarean section spontaneous_rupture membranes delivery mother temperature receive_intrapartum antibiotics unknown reason nicu called delivery infant emerged_grimace transferred warmer dried_stimulated given bulb_suctioning infant required facial cpap apgars one_minute five_minutes respectively transferred newborn_nursery noted dusky poor muscle_tone petechiae transferred nicu observation management physical_examination physical_examination admission showed birth weight_grams 5lb 8oz 25th_50th percentile_length 10th_25th percentile_head circumference_25th percentile heent_anterior fontanel_open flat molding mucous_membranes dry cyanotic circumoral_cyanosis chest clear auscultation grunting_flaring retracting heart normal rate_rhythm systolic_murmur grade femoral_pulses strong abdomen nontender positive bowel_sounds soft organomegaly_masses extremities_warm dry poor_perfusion skin pale scattered_petechiae chest lower abdomen back neuro poor tone decreased moro_grasp poor suck spine linear without dimples genitourinary_normal female_genitalia summary_hospital course_systems respiratory infant mild respiratory_distress admission nicu requiring nasal_cannula oxygen low flow approximately hours infant weaned room_air infant apneic_bradycardic episodes cardiovascular murmur audible admission resolved murmurs audible infant hemodynamically stable due maternal lithium exposure pregnancy ekg_done ekg showed borderline ekg wave flattening consistent age cardiology recommends ekg repeat weeks primary care pediatrician four_extremity blood_pressures normal infant passed_hyperoxia test chest_xray within normal_limits fluids_electrolytes nutrition due neurologic_concerns admission nicu infant made npo iv_fluids initiated enteral feedings started day_life infant weaned iv_fluids day infant currently feeding enfamil_calories per_ounce every three hours motyher taught concentrate formula using powder andor concentrate discharge weight_grams 4lb 9oz gastrointestinal bilirubin level drawn bilirubin repeat bilirubin level done result hematology blood_typing done infant hematocrit done birth platelet_count time hematocrits_platelets measured_infectious disease cbc blood_culture screened_admission nicu well lumbar_puncture due neurologic_concerns physical_examination lethargy decreased moro_grasp reflexes poor suck cbc within normal_limits lp also within normal_limits ampicillin_gentamycin started admission nicu subsequently_discontinued hours blood_culture remained negative clinical status improved endocrine due maternal lithium exposure pregnancy endocrinology_consulted tsh level drawn newborn day resulted level endocrinology_consulted followup levels thyroid panels done hours age free_t4 t4_tsh decreased time lithium level fu endocrinology recommends followup one week age repeating thyroid panel time neurology infant presented depressed neurologic system admission nicu subsequently_normalized etiology unknown resolved sensory_auditory hearing_screening performed_automated auditory_brain stem_responses infant passed_ears psychosocial mother sees psychotherapist name social_worker contact family social_worker reached_condition transfer good discharge_disposition home_name primary_pediatrician infant followed pediatrics suite care recommendations continue feeding every three hours enfamil_calories per_ounce followup dr medications_applicable iron_vitamin supplementation infants predominantly fed breast_milk receive_vitamin supplementation_in ...
# Median length: 37764

# %%
# Hyperparameters
embedding_dim = 100
num_convs = [64, 128, 256, 512]
hidden_dims = [1024, 512, 256]
drops = [0.3, 0.4, 0.5]
sz = 3
top_k = 8

# Training parameters
batch_size = 128
num_epochs = 5

# Prepossessing parameters
sequence_length = 210

input_shape = (sequence_length, embedding_dim)

model_input = Input(shape=input_shape)

z = Conv1D(filters=64, kernel_size=sz, strides=1, padding="same")(model_input)

for nc in num_convs:
    z = Conv1D(filters=nc, kernel_size=sz, strides=1, padding="same")(z)
    z = BatchNormalization()(z)
    z = Activation('relu')(z)
    
    z = Conv1D(filters=nc, kernel_size=sz, strides=1, padding="same")(z)
    z = BatchNormalization()(z)
    z = Activation('relu')(z)
    
    z = MaxPooling1D(pool_size=3, strides=2, padding="same")(z)

def _top_k(x):
    x = tf.transpose(x, [0, 2, 1])
    k_max = tf.nn.top_k(x, k=top_k)
    return tf.reshape(k_max[0], (-1, num_convs[-1] * top_k))

#z = Lambda(_top_k, output_shape=(num_convs[-1] * top_k,))(z)
z = Flatten()(z) 
for i, hd in enumerate(hidden_dims):
    z = Dense(hd, activation="relu")(z)
    z = Dropout(drops[i])(z)
model_output = Dense(1, activation="sigmoid")(z)

model = Model(model_input, model_output)
model.summary()
opt = Adam(beta_1=0.70, beta_2=0.99)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From /Users/scott/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1205: calling reduce_prod (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 210, 100)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 210, 64)           19264
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 210, 64)           12352
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 210, 64)           256
# _________________________________________________________________
# activation_1 (Activation)    (None, 210, 64)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 210, 64)           12352
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 210, 64)           256
# _________________________________________________________________
# activation_2 (Activation)    (None, 210, 64)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 105, 64)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 105, 128)          24704
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 105, 128)          512
# _________________________________________________________________
# activation_3 (Activation)    (None, 105, 128)          0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 105, 128)          49280
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 105, 128)          512
# _________________________________________________________________
# activation_4 (Activation)    (None, 105, 128)          0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 53, 128)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 53, 256)           98560
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 53, 256)           1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 53, 256)           0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 53, 256)           196864
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 53, 256)           1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 53, 256)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 27, 256)           0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 27, 512)           393728
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 27, 512)           2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 27, 512)           0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 27, 512)           786944
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 27, 512)           2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 27, 512)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 14, 512)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7168)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              7341056
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 9,599,169
# Trainable params: 9,595,329
# Non-trainable params: 3,840
# _________________________________________________________________
# WARNING:tensorflow:From /Users/scott/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1290: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
